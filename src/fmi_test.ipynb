# %%
# Import libraries (Jupyter knows about these libraries so a special import is not required)
from dlisio import dlis
from tqdm import tqdm
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from scipy import interpolate
from scipy import ndimage

# Ensure that we can see pandas tables of up to 1000 rows as DLIS parameter lists can be very long
pd.set_option('display.max_rows', 1000)

# %%
filenames = []
filenames.append("1-brsa-344-al_brsa_fmi1.DLIS")

import os.path
for fn in filenames:
    print(fn)
    print(os.path.exists(fn))
# Out:
# 1-brsa-344-al_brsa_fmi1.DLIS
# True

# %%
for fn in filenames:
    with dlis.load(fn) as files:
        print('Data contained in file: "', fn, '"\n')
        for f in files:
            print(f.describe())
# Out:
# Data contained in file: " 1-brsa-344-al_brsa_fmi1.DLIS "
#
# ------------
# Logical File
# ------------
# Description : LogicalFile(FMI_057LUP)
# Frames      : 4
# Channels    : 323
#
# Known objects
# --
# FILE-HEADER             : 1
# TOOL                    : 3
# PARAMETER               : 280
# CALIBRATION-MEASUREMENT : 22
# CALIBRATION-COEFFICIENT : 12
# CHANNEL                 : 323
# CALIBRATION             : 256
# PROCESS                 : 2
# EQUIPMENT               : 17
# ORIGIN                  : 1
# FRAME                   : 4
#
# Unknown objects
# --
# 440-PRESENTATION-DESCRIPTION : 1
# 440-OP-CHANNEL               : 323
# 440-CHANNEL                  : 289

# %%
with dlis.load(filenames[0]) as files:
    for f in files:
        for o in f.origins:
            print(o.describe())
# Out:
# ------
# Origin
# ------
# name   : DLIS_DEFINING_ORIGIN
# origin : 29
# copy   : 0
#
# Logical file ID          : FMI_057LUP
# File set name and number : PETROBRAS_OB/1-ROT-1-AL / 41
# File number and type     : 90 / DEPTH LOG
#
# Field                   : BTSEAL-2
# Well (id/name)          : 08115021276 / 1-BRSA-344-AL
# Produced by (code/name) : 440 / Schlumberger
# Produced for            : PETROBRAS
# Order number            : 1357
# Run number              : 1
# Descent number          : -1
# Created                 : 2005-04-20 07:06:09
#
# Created by              : OP, (version: 13C0-300)
# Other programs/services : FBSTB: Full-Bore Scanner - B           SGTN:
#                           Scintillation Gamma Ray Tool - N DTCH: DTS Telemetry
#                           Tool               LEHQT: Logging Equipment Head - QT
#                           DIP: Dip Computation                   HOLEV:
#                           Integrated Hole/Cement Volume

# %% [markdown]
# ### Loading the processed FMI DLIS logs

# %%
file = []
f, *tail = dlis.load(filenames[0])
lf, *tail = dlis.load(filenames[0])
file.append(lf)

# %%
def summarize(objs, **kwargs):
    """
    Create a pd.DataFrame that summarizes the content of 'objs', one object per row.
    
    Parameters
    ----------
    
    objs : list()
        list of metadata objects
        
    **kwargs
        Keyword arguments 
        Use kwargs to tell summarize() which fields (attributes) of the objects you want to include in the DataFrame. 
        The parameter name must match an attribute on the object in 'objs', while the value of the parameters is used
        as a column name. Any kwargs are excepted, but if the object does not have the requested attribute, 'KeyError' 
        is used as the value.
        
    Returns
    -------
    
    summary : pd.DataFrame
    """
    summary = []
    for attr, label in kwargs.items():
        column = []
        for obj in objs:
            try:
                value = getattr(obj, attr)
            except AttributeError:
                value = 'KeyError'
            except ValueError:
                value = 'Array'
            column.append(value)
        summary.append(column)
    summary = pd.DataFrame(summary).T
    summary.columns = kwargs.values()
    return summary

# %%
desc_parameters = ['CN', 'WN', 'FN',                                     # Well ID
                   'LOND', 'LATD',                                       # Well location
                   'DLAB', 'TLAB']                                       # Time and date of well logging

# Create a table out of the parameters in desc_parameters
parameter_table = summarize(file[0].parameters, name='Name', long_name='Long name', values='Value(s)')
desc_table = parameter_table.loc[parameter_table['Name'].isin(desc_parameters)].copy()

# Sort the table in the same order as desc_parameters
categorical_sorter = pd.Categorical(desc_parameters, desc_parameters, ordered=True)
desc_table['Name'] = desc_table['Name'].astype(categorical_sorter.dtype)
desc_table.sort_values(by='Name', inplace=True)

# Display the table
display(desc_table)
# Out:
#      Name              Long name         Value(s)
# 259    CN           Company Name      [PETROBRAS]
# 257    WN              Well Name  [1-BRSA-344-AL]
# 256    FN             Field Name       [BTSEAL-2]
# 79   LOND    Longitude (E=+ W=-)       [-36.0306]
# 80   LATD    Latitude (N=+ S=- )        [-9.8558]
# 237  DLAB  Date Logger At Bottom     [19/04/2005]
# 236  TLAB  Time Logger At Bottom          [23:00]

# %% [markdown]
# ### Listing channels

# %%
for f in file:
    for frame in f.frames:

        # Search through the channels for the index and obtain the units
        for channel in frame.channels:
            if channel.name == frame.index:
                depth_units = channel.units

        print(f'Frame Name: \t\t {frame.name}')
        print(f'Index Type: \t\t {frame.index_type}')
        print(f'Depth Interval: \t {frame.index_min} - {frame.index_max} {depth_units}')
        print(f'Depth Spacing: \t\t {frame.spacing} {depth_units}')
        print(f'Direction: \t\t {frame.direction}')
        print(f'Num of Channels: \t {len(frame.channels)}')
        print(f'Channel Names: \t\t {str(frame.channels)}')
        print('\n')
# Out:
# Frame Name: 		 60B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 154080 - 709440 0.1 in
# Depth Spacing: 		 -60 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 91
# Channel Names: 		 [Channel(TDEP), Channel(BS), Channel(CS), Channel(CVEL), Channel(TENS), Channel(ETIM), Channel(DEVIM), Channel(DEVI), Channel(RB_FBST), Channel(P1AZ_FBST), Channel(FFRE), Channel(FRSLL), Channel(FRSLH), Channel(XGMO), Channel(FCEV), Channel(FCV1), Channel(FCV2), Channel(U-FBST_DCXI), Channel(U-FBST_DCXV), Channel(DCHV), Channel(FCHV), Channel(DFCHV), Channel(FEPC), Channel(FXSP), Channel(FCVL), Channel(FCV0), Channel(FCVP), Channel(FCVN), Channel(FCBS), Channel(U-FCTS), Channel(FCIR), Channel(FSVL), Channel(FSVA), Channel(FSVB), Channel(FSVC), Channel(FSVD), Channel(FRHA), Channel(FRHD), Channel(FRLA), Channel(FRLD), Channel(PP), Channel(ANOR), Channel(FINC), Channel(HAZI), Channel(P1AZ), Channel(RB), Channel(SDEV), Channel(SDEVM), Channel(HAZIM), Channel(RB_GPIT), Channel(P1AZ_GPIT), Channel(GADZ), Channel(GPV), Channel(GNV), Channel(GAT), Channel(GMT), Channel(ECGR), Channel(HV), Channel(CTEM), Channel(SPCF), Channel(DPTR), Channel(DPAZ), Channel(QUAF), Channel(DDIP), Channel(DDA), Channel(DCAL), Channel(FCD), Channel(HDAR), Channel(U-FBST_ANOR_LOW), Channel(U-FBST_ANOR_HIGH), Channel(U-FBST_IMAGE_WIDTH), Channel(U-FBST_FBAV_LOW), Channel(RGR), Channel(TIME), Channel(SWFB), Channel(EI), Channel(FNOR), Channel(U-FBST_FNOR_LOW), Channel(U-FBST_FNOR_HIGH), Channel(GSW), Channel(BHPR), Channel(GTEM), Channel(DF), Channel(CDF), Channel(AREA), Channel(AFCD), Channel(ABS), Channel(IHV), Channel(ICV), Channel(U-FBST_CS_HIGH), Channel(GR)]
#
#
# Frame Name: 		 10B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 154090 - 709440 0.1 in
# Depth Spacing: 		 -10 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 4
# Channel Names: 		 [Channel(TDEP), Channel(IDWD), Channel(TIME), Channel(SCD)]
#
#
# Frame Name: 		 1B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 154081 - 709440 0.1 in
# Depth Spacing: 		 -1 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 42
# Channel Names: 		 [Channel(TDEP), Channel(TIME), Channel(EV), Channel(EV90), Channel(FBGA), Channel(FBAV), Channel(FB90), Channel(AEDI), Channel(FBDC), Channel(FB00), Channel(DB4A), Channel(DB3A), Channel(DB2A), Channel(DB1A), Channel(DB4), Channel(DB3), Channel(DB2), Channel(DB1), Channel(FCAX), Channel(FCAY), Channel(FCAZ), Channel(FTIM), Channel(AZSNG), Channel(AZS1G), Channel(FBCR), Channel(FCD4), Channel(FCD3), Channel(FCD2), Channel(FCD1), Channel(FCC4), Channel(FCC3), Channel(FCC2), Channel(FCC1), Channel(FCB4), Channel(FCB3), Channel(FCB2), Channel(FCB1), Channel(FCA4), Channel(FCA3), Channel(FCA2), Channel(FCA1), Channel(AZS2G)]
#
#
# Frame Name: 		 15B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 154095 - 709440 0.1 in
# Depth Spacing: 		 -15 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 12
# Channel Names: 		 [Channel(TDEP), Channel(TIME), Channel(RC1), Channel(RC2), Channel(C1), Channel(C2), Channel(AX), Channel(AY), Channel(AZ), Channel(FX), Channel(FY), Channel(FZ)]

# %%
# Static FMI channels
channel_table = summarize(file[0].channels, name='Channel Name', units='Units', dimension='Dimension', frame='Frame')
channel_table.sort_values('Channel Name')
# Out:
#            Channel Name   Units Dimension       Frame
# 110                 ABS      m2       [1]  Frame(60B)
# 167                AEDI               [1]   Frame(1B)
# 109                AFCD      m2       [1]  Frame(60B)
# 72                 ANOR    m/s2       [1]  Frame(60B)
# 305             ANOR_SL    m/s2       [1]        None
# 108                AREA      m2       [1]  Frame(60B)
# 61                AVCC1       V       [1]        None
# 62                AVCC2       V       [1]        None
# 287                  AX    m/s2       [1]  Frame(15B)
# 312               AX_SL    m/s2       [1]        None
# 288                  AY    m/s2       [1]  Frame(15B)
# 313               AY_SL    m/s2       [1]        None
# 289                  AZ    m/s2       [1]  Frame(15B)
# 298               AZS1G    m/s2       [1]   Frame(1B)
# 299               AZS2G    m/s2       [1]   Frame(1B)
# 297               AZSNG               [1]   Frame(1B)
# 314               AZ_SL    m/s2       [1]        None
# 92                 BHPR     kPa       [1]  Frame(60B)
# 91                 BHRM   ohm.m       [1]        None
# 26                   BS      in       [1]  Frame(60B)
# 285                  C1      in       [1]  Frame(15B)
# 286                  C2      in       [1]  Frame(15B)
# 98                  CDF       N       [1]  Frame(60B)
# 27                   CS    ft/h       [1]  Frame(60B)
# 96                 CTEM    degC       [1]  Frame(60B)
# 28                 CVEL  ft/min       [1]  Frame(60B)
# 213                 DB1               [1]        None
# 211                 DB1               [1]   Frame(1B)
# 212                 DB1               [1]        None
# 200                DB1A               [1]        None
# 199                DB1A               [1]   Frame(1B)
# 201                DB1A               [1]        None
# 158            DB1A_COR               [1]        None
# 154             DB1_COR               [1]        None
# 209                 DB2               [1]        None
# 210                 DB2               [1]        None
# 208                 DB2               [1]   Frame(1B)
# 198                DB2A               [1]        None
# 197                DB2A               [1]        None
# 196                DB2A               [1]   Frame(1B)
# 159            DB2A_COR               [1]        None
# 155             DB2_COR               [1]        None
# 207                 DB3               [1]        None
# 206                 DB3               [1]        None
# 205                 DB3               [1]   Frame(1B)
# 194                DB3A               [1]        None
# 195                DB3A               [1]        None
# 193                DB3A               [1]   Frame(1B)
# 160            DB3A_COR               [1]        None
# 156             DB3_COR               [1]        None
# 202                 DB4               [1]   Frame(1B)
# 204                 DB4               [1]        None
# 203                 DB4               [1]        None
# 192                DB4A               [1]        None
# 191                DB4A               [1]        None
# 190                DB4A               [1]   Frame(1B)
# 161            DB4A_COR               [1]        None
# 157             DB4_COR               [1]        None
# 111                DCAL      in       [1]  Frame(60B)
# 48                 DCHV       V       [1]  Frame(60B)
# 107                 DDA     deg       [1]  Frame(60B)
# 106                DDIP     deg       [1]  Frame(60B)
# 33                 DEVI     deg       [1]  Frame(60B)
# 32                DEVIM     deg       [1]  Frame(60B)
# 97                   DF       N       [1]  Frame(60B)
# 50                DFCHV               [1]  Frame(60B)
# 103                DPAZ     deg       [1]  Frame(60B)
# 102                DPTR     deg       [1]  Frame(60B)
# 89                 ECGR    gAPI       [1]  Frame(60B)
# 151                EHGR    gAPI       [1]        None
# 43                   EI      mA       [1]  Frame(60B)
# 30                 ETIM       s       [1]  Frame(60B)
# 162                  EV       V       [1]   Frame(1B)
# 163                EV90       V       [1]   Frame(1B)
# 187                FB00               [1]   Frame(1B)
# 189                FB00               [1]        None
# 188                FB00               [1]        None
# 166                FB90               [1]   Frame(1B)
# 150                FBA1             [720]        None
# 149                FBA1             [720]        None
# 147                FBA2             [720]        None
# 148                FBA2             [720]        None
# 146                FBA3             [720]        None
# 145                FBA4             [720]        None
# 229              FBAA_A              [50]        None
# 228              FBAA_A              [50]        None
# 227              FBAA_P              [50]        None
# 226              FBAA_P              [50]        None
# 225              FBAB_A              [50]        None
# 224              FBAB_A              [50]        None
# 223              FBAB_P              [50]        None
# 222              FBAB_P              [50]        None
# 220              FBAC_A              [50]        None
# 221              FBAC_A              [50]        None
# 218              FBAC_P              [50]        None
# 219              FBAC_P              [50]        None
# 216              FBAD_A              [50]        None
# 217              FBAD_A              [50]        None
# 214              FBAD_P              [50]        None
# 215              FBAD_P              [50]        None
# 165                FBAV               [1]   Frame(1B)
# 143                FBB1             [720]        None
# 144                FBB1             [720]        None
# 142                FBB2             [720]        None
# 141                FBB2             [720]        None
# 140                FBB3             [720]        None
# 139                FBB4             [720]        None
# 137                FBC1             [720]        None
# 138                FBC1             [720]        None
# 136                FBC2             [720]        None
# 135                FBC2             [720]        None
# 134                FBC3             [720]        None
# 133                FBC4             [720]        None
# 186                FBCR     ohm       [1]   Frame(1B)
# 132                FBD1             [720]        None
# 131                FBD1             [720]        None
# 130                FBD2             [720]        None
# 129                FBD2             [720]        None
# 128                FBD3             [720]        None
# 127                FBD4             [720]        None
# 168                FBDC               [1]   Frame(1B)
# 164                FBGA      dB       [1]   Frame(1B)
# 276                FCA1              [12]   Frame(1B)
# 277                FCA1              [12]        None
# 274             FCA1_CV              [12]        None
# 275             FCA1_CV              [12]        None
# 273                FCA2              [12]        None
# 272                FCA2              [12]   Frame(1B)
# 271             FCA2_CV              [12]        None
# 270             FCA2_CV              [12]        None
# 269                FCA3              [12]   Frame(1B)
# 268             FCA3_CV              [12]        None
# 267                FCA4              [12]   Frame(1B)
# 266             FCA4_CV              [12]        None
# 293                FCAX    m/s2       [1]   Frame(1B)
# 294                FCAY    m/s2       [1]   Frame(1B)
# 295                FCAZ    m/s2       [1]   Frame(1B)
# 265                FCB1              [12]        None
# 264                FCB1              [12]   Frame(1B)
# 263             FCB1_CV              [12]        None
# 262             FCB1_CV              [12]        None
# 261                FCB2              [12]        None
# 260                FCB2              [12]   Frame(1B)
# 259             FCB2_CV              [12]        None
# 258             FCB2_CV              [12]        None
# 257                FCB3              [12]   Frame(1B)
# 256             FCB3_CV              [12]        None
# 255                FCB4              [12]   Frame(1B)
# 254             FCB4_CV              [12]        None
# 57                 FCBS       V       [1]  Frame(60B)
# 252                FCC1              [12]   Frame(1B)
# 253                FCC1              [12]        None
# 250             FCC1_CV              [12]        None
# 251             FCC1_CV              [12]        None
# 249                FCC2              [12]        None
# 248                FCC2              [12]   Frame(1B)
# 246             FCC2_CV              [12]        None
# 247             FCC2_CV              [12]        None
# 245                FCC3              [12]   Frame(1B)
# 244             FCC3_CV              [12]        None
# 243                FCC4              [12]   Frame(1B)
# 242             FCC4_CV              [12]        None
# 112                 FCD      in       [1]  Frame(60B)
# 241                FCD1              [12]        None
# 240                FCD1              [12]   Frame(1B)
# 238             FCD1_CV              [12]        None
# 239             FCD1_CV              [12]        None
# 237                FCD2              [12]        None
# 236                FCD2              [12]   Frame(1B)
# 235             FCD2_CV              [12]        None
# 234             FCD2_CV              [12]        None
# 233                FCD3              [12]   Frame(1B)
# 232             FCD3_CV              [12]        None
# 231                FCD4              [12]   Frame(1B)
# 230             FCD4_CV              [12]        None
# 42                 FCEV       V       [1]  Frame(60B)
# 49                 FCHV       V       [1]  Frame(60B)
# 59                 FCIR       V       [1]  Frame(60B)
# 54                 FCV0       V       [1]  Frame(60B)
# 44                 FCV1       V       [1]  Frame(60B)
# 45                 FCV2       V       [1]  Frame(60B)
# 53                 FCVL       V       [1]  Frame(60B)
# 56                 FCVN       V       [1]  Frame(60B)
# 55                 FCVP       V       [1]  Frame(60B)
# 51                 FEPC               [1]  Frame(60B)
# 37                 FFRE       %       [1]  Frame(60B)
# 74                 FINC     deg       [1]  Frame(60B)
# 307             FINC_SL     deg       [1]        None
# 73                 FNOR     A/m       [1]  Frame(60B)
# 306             FNOR_SL     A/m       [1]        None
# 41                 FPDB     deg       [1]        None
# 67                 FRHA       V       [1]  Frame(60B)
# 68                 FRHD       V       [1]  Frame(60B)
# 69                 FRLA       V       [1]  Frame(60B)
# 70                 FRLD       V       [1]  Frame(60B)
# 39                FRSLH               [1]  Frame(60B)
# 38                FRSLL               [1]  Frame(60B)
# 63                 FSVA       V       [1]  Frame(60B)
# 119            FSVA_LOW       V       [1]        None
# 64                 FSVB       V       [1]  Frame(60B)
# 118            FSVB_LOW       V       [1]        None
# 65                 FSVC       V       [1]  Frame(60B)
# 117            FSVC_LOW       V       [1]        None
# 66                 FSVD       V       [1]  Frame(60B)
# 116            FSVD_LOW       V       [1]        None
# 60                 FSVL       V       [1]  Frame(60B)
# 296                FTIM      ms       [1]   Frame(1B)
# 290                  FX     A/m       [1]  Frame(15B)
# 52                 FXSP       V       [1]  Frame(60B)
# 315               FX_SL     A/m       [1]        None
# 291                  FY     A/m       [1]  Frame(15B)
# 316               FY_SL     A/m       [1]        None
# 292                  FZ     A/m       [1]  Frame(15B)
# 317               FZ_SL     A/m       [1]        None
# 83                 GADZ       V       [1]  Frame(60B)
# 318             GADZ_SL       V       [1]        None
# 86                  GAT    degC       [1]  Frame(60B)
# 321              GAT_SL    degC       [1]        None
# 90                  GHD      in       [1]        None
# 87                  GMT    degC       [1]  Frame(60B)
# 322              GMT_SL    degC       [1]        None
# 85                  GNV       V       [1]  Frame(60B)
# 320              GNV_SL       V       [1]        None
# 84                  GPV       V       [1]  Frame(60B)
# 319              GPV_SL       V       [1]        None
# 302                  GR    gAPI       [1]  Frame(60B)
# 88                  GSW               [1]  Frame(60B)
# 93                 GTEM    degF       [1]  Frame(60B)
# 75                 HAZI     deg       [1]  Frame(60B)
# 80                HAZIM     deg       [1]  Frame(60B)
# 308             HAZI_SL     deg       [1]        None
# 113                HDAR      in       [1]  Frame(60B)
# 304                 HGR    gAPI       [1]        None
# 95                   HV       V       [1]  Frame(60B)
# 115                 ICV      m3       [1]  Frame(60B)
# 152                IDWD  0.1 in       [1]  Frame(10B)
# 114                 IHV      m3       [1]  Frame(60B)
# 31                 MARK      ft       [1]        None
# 76                 P1AZ     deg       [1]  Frame(60B)
# 35            P1AZ_FBST     deg       [1]  Frame(60B)
# 82            P1AZ_GPIT     deg       [1]  Frame(60B)
# 309             P1AZ_SL     deg       [1]        None
# 71                   PP               [1]  Frame(60B)
# 104                QUAF               [1]  Frame(60B)
# 77                   RB     deg       [1]  Frame(60B)
# 184                 RB1               [1]        None
# 175                RB10               [1]        None
# 174                RB11               [1]        None
# 173                RB12               [1]        None
# 172                RB13               [1]        None
# 171                RB14               [1]        None
# 170                RB15               [1]        None
# 169                RB16               [1]        None
# 183                 RB2               [1]        None
# 182                 RB3               [1]        None
# 181                 RB4               [1]        None
# 180                 RB5               [1]        None
# 179                 RB6               [1]        None
# 178                 RB7               [1]        None
# 177                 RB8               [1]        None
# 176                 RB9               [1]        None
# 185                RBSV               [1]        None
# 34              RB_FBST     deg       [1]  Frame(60B)
# 81              RB_GPIT     deg       [1]  Frame(60B)
# 310               RB_SL     deg       [1]        None
# 283                 RC1      in       [1]  Frame(15B)
# 284                 RC2      in       [1]  Frame(15B)
# 300                 RGR    gAPI       [1]  Frame(60B)
# 303                RHGR    gAPI       [1]        None
# 153                 SCD  0.1 in       [1]  Frame(10B)
# 78                 SDEV     deg       [1]  Frame(60B)
# 79                SDEVM     deg       [1]  Frame(60B)
# 311             SDEV_SL     deg       [1]        None
# 99                 SPCF               [1]  Frame(60B)
# 301                STSG               [1]        None
# 36                 SWFB               [1]  Frame(60B)
# 10                 TDEP  0.1 in       [1]        None
# 4                  TDEP  0.1 in       [1]  Frame(15B)
# 8                  TDEP  0.1 in       [1]        None
# 5                  TDEP  0.1 in       [1]        None
# 11                 TDEP  0.1 in       [1]        None
# 7                  TDEP  0.1 in       [1]        None
# 1                  TDEP  0.1 in       [1]        None
# 6                  TDEP  0.1 in       [1]        None
# 2                  TDEP  0.1 in       [1]  Frame(10B)
# 3                  TDEP  0.1 in       [1]   Frame(1B)
# 9                  TDEP  0.1 in       [1]        None
# 12                 TDEP  0.1 in       [1]        None
# 0                  TDEP  0.1 in       [1]  Frame(60B)
# 94                 TEMP    degF       [1]        None
# 29                 TENS     lbf       [1]  Frame(60B)
# 21                 TIME      ms       [1]        None
# 22                 TIME      ms       [1]        None
# 24                 TIME      ms       [1]        None
# 23                 TIME      ms       [1]        None
# 13                 TIME      ms       [1]  Frame(60B)
# 25                 TIME      ms       [1]        None
# 15                 TIME      ms       [1]  Frame(10B)
# 16                 TIME      ms       [1]   Frame(1B)
# 17                 TIME      ms       [1]  Frame(15B)
# 18                 TIME      ms       [1]        None
# 19                 TIME      ms       [1]        None
# 20                 TIME      ms       [1]        None
# 14                 TIME      ms       [1]        None
# 101        U-DIP_CENTER               [1]        None
# 100       U-DIP_COSLOPE     deg       [1]        None
# 105         U-DIP_SLOPE     deg       [1]        None
# 280            U-FBPHEV     deg       [1]        None
# 281            U-FBPHPB     deg       [1]        None
# 282          U-FBSATIND       V       [1]        None
# 123    U-FBST_ANOR_HIGH    m/s2       [1]  Frame(60B)
# 122     U-FBST_ANOR_LOW    m/s2       [1]  Frame(60B)
# 124      U-FBST_CS_HIGH     m/h       [1]  Frame(60B)
# 46          U-FBST_DCXI      mA       [1]  Frame(60B)
# 47          U-FBST_DCXV       V       [1]  Frame(60B)
# 126     U-FBST_FBAV_LOW               [1]  Frame(60B)
# 121    U-FBST_FNOR_HIGH     A/m       [1]  Frame(60B)
# 120     U-FBST_FNOR_LOW     A/m       [1]  Frame(60B)
# 125  U-FBST_IMAGE_WIDTH               [1]  Frame(60B)
# 58               U-FCTS       V       [1]  Frame(60B)
# 278             U-FFRSH               [1]        None
# 279             U-FFRSL               [1]        None
# 40                 XGMO               [1]  Frame(60B)

# %%
import openpyxl
channel_table.to_excel('curvas_arquivo_fmi.xlsx', index=False)

# %%
def get_frame(logical_file, name):
    """
    Return a frame with a given name within a logical file
    """
    [frame] = [x for x in logical_file.frames if x.name == name]
    return frame

def index_of(frame):
    """
    Return the index channel of the frame
    """
    return next(ch for ch in frame.channels if ch.name == frame.index)

def get_channel(frame, name):
    """
    Get a channel with a given name from a given frame; fail if the frame does not have exactly one such channel
    """
    [channel] = [x for x in frame.channels if x.name == name]
    return channel

# %%
# Specify frames and channels to lookup
lookup_frame = ['None', 'None']
lookup_channel = ['FBB1', 'FBD1']

# Set arrays to hold output
fmi = []
depth = []
fmi_image = []

# Iterate over the static and dynamic files
for i in range(2):

    # Get frame and its index channel
    fmi_frame = get_frame(file[i], lookup_frame[i])
    fmi_index = index_of(fmi_frame)

    # Get the metadata
    fmi.append(get_channel(fmi_frame, lookup_channel[i]))
    fmi_curves = fmi_frame.curves()
    depth.append(fmi_curves[fmi_frame.index])
    fmi_image.append(fmi_curves[lookup_channel[i]])

    # Print out the properties of the channel/curve
    print('Shape of depth index curve array: \t', depth[i].shape)
    print('Shape of FMI curve array:\t', fmi_image[i].shape)
    print(f'Name: \t\t{fmi[i].name}')
    print(f'Long Name: \t{fmi[i].long_name}')
    print(f'Units: \t\t{fmi[i].units}')
    print(f'Properties: \t{fmi[i].properties}')
    print(f'Dimension: \t{fmi[i].dimension}') #if >1, then data is an array
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 14
#      10 # Iterate over the static and dynamic files
#      11 for i in range(2):
#      12
#      13     # Get frame and its index channel
# ---> 14     fmi_frame = get_frame(file[i], lookup_frame[i])
#      15     fmi_index = index_of(fmi_frame)
#      17     # Get the metadata
#
# Cell In[19], line 5, in get_frame(logical_file, name)
#       1 def get_frame(logical_file, name):
#       2     """
#       3     Return a frame with a given name within a logical file
#       4     """
# ----> 5     [frame] = [x for x in logical_file.frames if x.name == name]
#       6     return frame
#
# ValueError: not enough values to unpack (expected 1, got 0)

# %%
def paint_channel(ax, curve, y_axis, x_axis, **kwargs):
    """
    Plot an image channel into a matplotlib axes using an index channel for the y-axis
    
    Parameters
    ----------
    
        ax : matplotlib.axes
        
        curve : numpy array
            The curve to be plotted
        
        y_axis : numpy array 
            An array of values that defines the y-axis
                
        x_axis : numpy array 
            An array of values that defines the x-axis
            
        **kwargs : dict 
            Keyword arguments to be passed on to ax.imshow()
    """
    # Determine the extent of the image so that the pixel centres correspond with the correct axis values
    dx = np.mean(x_axis[1:] - x_axis[:-1])
    dy = np.mean(y_axis[1:] - y_axis[:-1])
    extent = (x_axis[0] - dx/2, x_axis[-1] + dx/2, y_axis[0] - dy/2, y_axis[-1] + dy/2)
    
    # Determine the correct orientation of the image
    if y_axis[1] < y_axis[0]:   # Frame recorded from the bottom to the top of the well
        origin = 'lower'
    else:                       # Frame recorded from the top to the bottom of the well
        origin = 'upper'
    
    return ax.imshow(curve, aspect='auto', origin=origin, extent=extent, **kwargs)

# %%
def fmi_plot(MinDepth, MaxDepth, StaticFMI, DynamicFMI):   

    # Determine the maximum absolute value so that we can balance the colormap maximum value
    fmi_static_max = np.percentile(np.abs(fmi_image[0]), StaticFMI)
    fmi_dynamic_max = np.percentile(np.abs(fmi_image[1]), DynamicFMI)
    
    # Parameters for plotting the waveforms
    fmi_static_pltargs = {
        'cmap': 'YlOrBr',
        'vmin': 0,
        'vmax': fmi_static_max,
    }
    fmi_dynamic_pltargs = {
        'cmap': 'YlOrBr',
        'vmin': 0,
        'vmax': fmi_dynamic_max,
    }    
    
    fmi_samples = np.arange(fmi[0].dimension[0]) # x values to use in plotting

    # Create figure and axes
    fig, axes = plt.subplots(ncols=2, figsize=(10, 20), constrained_layout=True)

    # Plot static data as a colourmapped image
    ax = axes[0]
    im = paint_channel(ax, fmi_image[0], depth[0], fmi_samples, **fmi_static_pltargs)
    cbar = fig.colorbar(im, ax=ax, location='top')
    cbar.set_label(f'{fmi[0].name}: {fmi[0].long_name}')
    ax.set(ylim=[MaxDepth, MinDepth], ylabel='Depth $z$ [ft]')

    # Plot dynamic data as a colourmapped image
    ax = axes[1]
    im = paint_channel(ax, fmi_image[1], depth[1], fmi_samples, **fmi_dynamic_pltargs)
    cbar = fig.colorbar(im, ax=ax, location='top')
    cbar.set_label(f'{fmi[1].name}: {fmi[1].long_name}')
    ax.set(ylim=[MaxDepth, MinDepth])
    
    for ax in axes:
        ax.set(xlim=[0,360], xticks=np.arange(0, 360, 45), xlabel='Image Orientation [deg]')
        ax.grid(True)

fmi_plot(depth[0].min(), depth[0].max(), 50, 50)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 42
#      39         ax.set(xlim=[0,360], xticks=np.arange(0, 360, 45), xlabel='Image Orientation [deg]')
#      40         ax.grid(True)
# ---> 42 fmi_plot(depth[0].min(), depth[0].max(), 50, 50)
#
# IndexError: list index out of range
